# %% [markdown]
# # NN-Subsampling Algorithm
#
# The sampling algorithm is an iterative process based on Nearest Neighbour search.
#
# In each iteration, the dataset is normalized with the standard scaler (mean = 0, standard deviation = 1) and a nearest-neighbour model is constructed and queried to find the nearest neighbor for each data point as well as the distance between them. If the distance is below a certain cutoff distance, the neighbor is removed with some probability. The process is iterated until there are no more points to be removed.
#
# The algorithm has two hyper-parameters: cutoff distance and deletion probability (rate).
#
# The cutoff distance controls the sparsity of the resulting representative dataset. Higher cutoff distances resulting in fewer sub-sampled points.
# The deletion probability controls robustness. Lower deletion probablibity is more robust but resulting in slower execution. High deletion probablity might result in a "hole" in the subsampled dataset
#
# High-dimensional datasets may also be pre-processed by principal component analysis (PCA) to reduce the dimensionality prior to subsampling
#
#
# The illustration of the subsampling procedure is shown in the Figure below
#
# <center>
#     <img src="./subsample_schema.JPG" width = 500>
# </center>

# %% [markdown]
# The Nearest-Neighbour search uses one of the packages below:
#
# * FLANN: http://www.cs.ubc.ca/research/flann/
#
# * pykdtree: https://github.com/storpipfugl/pykdtree
#
# * Annoy: https://github.com/spotify/annoy
#
# * nmslib: https://github.com/nmslib/nmslib/tree/master/python_bindings
#
# * scipy cKDTree
#
# * scikit-learn nearest neighbor
#
# Please make sure you have at least one of these packages installed before trying the algorithm (also remember to specify the method in your script)
#
# Also note that different packages may (sometimes very significantly) in speed, efficiency and result

# %% [markdown]
# ## importing the functions

# %%
from NNSubsampling import subsampling, subsampling_with_PCA, \
                          batch_subsampling, batch_subsampling_with_PCA

# %% [markdown]
# ## Detailed Explanations of the Functions
# ### Subsampling
#
# subsampling(data, list_desc = [], standard_scale = True, cutoff_sig = 0.05, rate = 0.3, method = "pykdtree", verbose = True):
#
#     Run the NN-based subsampling algorithm to a list of data points and
#     return the resulting list of subsampled data points
#
#
#     Parameters
#     -------------
#     data: List. the original list of data points
#
#     list_desc [[] (empty list)]:  List.
#                 the indices of descriptors (features) of the datapoints.
#                 The algorithm would subsample based only on these descriptors
#                 (although other features will still be kept in the resulting subsampled dataset)
#                 If the list is empty, then all feature will be taken into account
#
#     standard_scale [True]: Boolean. Whether to apply standard scaler to the dataset prior to subsampling
#
#     cutoff_sig [0.02]: Float. cutoff significance. the cutoff distance equals to the Euclidean
#                        norm of the standard deviations in all dimensions of the data points
#
#     rate [0.3]: Float. possibility of deletion
#
#     method ["pykdtree"]: String. which backend nearest neighbour model to use.
#                          possible choices: ["pykdtree", "nmslib", "sklearn", "scipy", "annoy", "flann"]
#
#     verbose [True]: Boolean. whether to output result of each iteration
#
#
#     Return
#     -------------
#     sampling_result : the result list of subsampled data points

# %% [markdown]
# ### subsampling_with_PCA
# subsampling_with_PCA(data, list_desc = [], standard_scale = True, cutoff_sig = 0.05, rate = 0.3,
#                                 start_trial_component = 10, max_component = 30, target_variance = 0.999999,
#                                 method = "pykdtree", verbose = True):
#
#     Run the NN-based subsampling algorithm to a list of data points and
#     return the resulting list of subsampled data points
#
#     The data set will first be transformed by PCA, before running the subsampling algorithm
#     The number of PCs kept is the minimal number of PCs that have sum explained variance
#     greater than target_variance
#
#     Note that the final resulting list of datapoints (sampling_result) is NOT transformed
#     (since we only used the PCA + subsampling alghorithm to find the indices of the datapoints to be kept)
#
#
#     Parameters
#     -------------
#     data: List. the original list of data points
#
#     list_desc [[] (empty list)]:  List.
#                 the indices of descriptors (features) of the datapoints.
#                 The algorithm would subsample based only on these descriptors
#                 (although other features will still be kept in the resulting subsampled dataset)
#                 If the list is empty, then all feature will be taken into account
#
#     standard_scale [True]: Boolean. Whether to apply standard scaler to the dataset prior to subsampling
#
#     cutoff_sig [0.02]: Float. cutoff significance. the cutoff distance equals to the Euclidean
#                        norm of the standard deviations in all dimensions of the data points
#
#     rate [0.3]: Float. possibility of deletion
#
#     start_trial_component [10]: Int. minimum number of PCs.
#                            if the number of features is below this number, then all features will be kept
#
#     max_component [30]: Int.the maximum number of PCs to be kept,
#                         even the target variance has not been reached
#
#     target_variance [0.999999]: Float. the target sum of variance.
#
#     method ["pykdtree"]: String. which backend nearest neighbour model to use.
#                          possible choices: ["pykdtree", "nmslib", "sklearn", "scipy", "annoy", "flann"]
#
#     verbose [True]: Boolean. whether to output result of each iteration
#
#
#     Return
#     -------------
#     sampling_result : the result list of subsampled data points

# %% [markdown]
# ### batch_subsampling
# batch_subsampling(data, list_desc = [], batch_size = 1000000, recursive_level = 1,
#                              standard_scale = True, cutoff_sig = 0.05, rate = 0.3, method = "pykdtree",
#                              verbose = True, shuffle = True):
#
#     Subsample with batch
#     This is to save the memory if the data set of interest is too large.
#
#     The data set will first be broken down into equally sized batchs (defined by batch size)
#     that will be subsampled individually.
#     The resulting subsampled datapoints will then be pooled together for a overall subsample
#
#     In case this is not sufficient, multi-level batch subsampling is also allowed.
#     So instead of a overall subsample after pooling the resulting subsampled datapoints,
#     the pooled data points will again be broken down into batches for a second-level batch subsample.
#     This process is repeated multiple times (as defined by recursive_level) before eventually an
#     overall subsample is performed
#
#
#     Parameters
#     -------------
#     data: List. the original list of data points
#
#     list_desc [[] (empty list)]:  List.
#                 the indices of descriptors (features) of the datapoints.
#                 The algorithm would subsample based only on these descriptors
#                 (although other features will still be kept in the resulting subsampled dataset)
#                 If the list is empty, then all feature will be taken into account
#
#     batch_size [1000000]: Int. the number of datapoints in each batch
#
#     recursive_level [1]: Int. the number of levels for batch subsampling (as described above)
#
#     standard_scale [True]: Boolean. Whether to apply standard scaler to the dataset prior to subsampling
#
#     cutoff_sig [0.02]: Float. cutoff significance. the cutoff distance equals to the Euclidean
#                        norm of the standard deviations in all dimensions of the data points
#
#     rate [0.3]: Float. possibility of deletion
#
#     method ["pykdtree"]: String. which backend nearest neighbour model to use.
#                          possible choices: ["pykdtree", "nmslib", "sklearn", "scipy", "annoy", "flann"]
#
#     verbose [True]: Boolean. whether to output result of each iteration
#
#     shuffle [True]: Boolean. whether to shuffle the dataset before breaking down into batchs
#
#
#     Return
#     -------------
#     sampling_result : the result list of subsampled data points

# %% [markdown]
# ### batch_subsampling_with_PCA
#
# batch_subsampling_with_PCA(data, list_desc = [], batch_size = 1000000, recursive_level = 1,
#                              start_trial_component = 10, max_component = 30, target_variance = 0.999999,
#                              standard_scale = True, cutoff_sig = 0.05, rate = 0.3, method = "pykdtree",
#                              verbose = True, shuffle = True):
#
#     '''
#     Subsample with batch (with PCA pre-processing)
#     This is to save the memory if the data set of interest is too large.
#
#     The data set will first be broken down into equally sized batchs (defined by batch size)
#     that will be subsampled individually.
#     The resulting subsampled datapoints will then be pooled together for a overall subsample
#
#     In case this is not sufficient, multi-level batch subsampling is also allowed.
#     So instead of a overall subsample after pooling the resulting subsampled datapoints,
#     the pooled data points will again be broken down into batches for a second-level batch subsample.
#     This process is repeated multiple times (as defined by recursive_level) before eventually an
#     overall subsample is performed
#
#
#     Parameters
#     -------------
#     data: List. the original list of data points
#
#     list_desc [[] (empty list)]:  List.
#                 the indices of descriptors (features) of the datapoints.
#                 The algorithm would subsample based only on these descriptors
#                 (although other features will still be kept in the resulting subsampled dataset)
#                 If the list is empty, then all feature will be taken into account
#
#     batch_size [1000000]: Int. the number of datapoints in each batch
#
#     recursive_level [1]: Int. the number of levels for batch subsampling (as described above)
#
#     standard_scale [True]: Boolean. Whether to apply standard scaler to the dataset prior to subsampling
#
#     cutoff_sig [0.02]: Float. cutoff significance. the cutoff distance equals to the Euclidean
#                        norm of the standard deviations in all dimensions of the data points
#
#     rate [0.3]: Float. possibility of deletion
#
#     start_trial_component [10]: Int. minimum number of PCs.
#                            if the number of features is below this number, then all features will be kept
#
#     max_component [30]: Int.the maximum number of PCs to be kept,
#                         even the target variance has not been reached
#
#     target_variance [0.999999]: Float. the target sum of variance.
#
#     method ["pykdtree"]: String. which backend nearest neighbour model to use.
#                          possible choices: ["pykdtree", "nmslib", "sklearn", "scipy", "annoy", "flann"]
#
#     verbose [True]: Boolean. whether to output result of each iteration
#
#     shuffle [True]: Boolean. whether to shuffle the dataset before breaking down into batchs
#
#
#     Return
#     -------------
#     sampling_result : the result list of subsampled data points

# %% [markdown]
# ## Tests
#
# ### prepare plot function and dataset
#
# Multi-dimensional normal distributed dataset

# %%
import time
import numpy as np
import random
import seaborn as sns
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
def plot(data):
    
    x_subsampled = data[:,0]
    y_subsampled = data[:,1]

    dataframe = pd.DataFrame({'x':x_subsampled, 'y':y_subsampled, 'group':np.repeat('subsampled',len(x_subsampled))})
    sns.set(font_scale = 2)
    with sns.axes_style('white'):
        #g = sns.jointplot('x', 'y', data=dataframe,size=10,s=2,stat_func=None,marker='o', space = 0)
        g = sns.JointGrid(x="x", y="y",data=dataframe,space=0)
        g = g.plot_joint(plt.scatter, color = "b", s=30)

        g.set_axis_labels(fontsize=50)

        count = lambda a, b: len(a)
        g.annotate(count, template="{val:.0f}",stat="Count",loc="upper right", fontsize = 20)

        _ = g.ax_marg_x.hist(dataframe["x"], color = "b", alpha = 0.6, bins = np.arange(-0.5, 0.5, 0.02))
        _ = g.ax_marg_y.hist(dataframe["y"], color = "b", alpha = 0.6, orientation = "horizontal",bins = np.arange(0, 200, 4))
        plt.show()
    return

n = 1000000
x1_mu, x1_sigma = 0, 0.1
x2_mu, x2_sigma = 100, 20
x3_mu, x3_sigma = 15, 40
x4_mu, x4_sigma = -20, 5
x5_mu, x5_sigma = 1000, 0.1
x6_mu, x7_sigma = 0.0, 30
x7_mu, x6_sigma = 12, 2
x8_mu, x8_sigma = 50, 40
x9_mu, x9_sigma = 5, 20
x10_mu, x10_sigma = 10, 2


x1 = np.random.normal(x1_mu, x1_sigma, n)
x2 = np.random.normal(x2_mu, x2_sigma, n)
x3 = np.random.normal(x3_mu, x3_sigma, n)
x4 = np.random.normal(x4_mu, x4_sigma, n)
x5 = np.random.normal(x5_mu, x5_sigma, n)
x6 = np.random.normal(x6_mu, x6_sigma, n)
x7 = np.random.normal(x7_mu, x7_sigma, n)
x8 = np.random.normal(x8_mu, x8_sigma, n)
x9 = np.random.normal(x9_mu, x9_sigma, n)
x10 = np.random.normal(x10_mu, x10_sigma, n)

# %% [markdown]
# ### Test 1: 2D toy case
#
# Test the subsampling algorithm with different "rate" and "cutoff_sig" settings, with a 2D toy dataset
# #### in this test case, we only used pykdtree backend
#
# 2 observations can be made:
# 1. higher rate --> fewer iterations, faster execution, but less nicely distributed results
# 2. higher cutoff_sig --> more sparse resulting subsampled datapoints

# %%
data_2D = np.column_stack((x1,x2))
plot(data_2D)
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# #### subsample with cutoff_sig = 0.05, rate = 0.2

# %%
start = time.time()
subsampled = np.asarray(subsampling(data_2D,list_desc = [],cutoff_sig=0.1,rate=0.2, method = "pykdtree"))
print("\n\ntotal time: {}".format(time.time()-start))

plot(subsampled)
# Out:
# Started NN-subsampling, original length: 1000000
# use pykdtree backend
# Subample with standard scaled data
# start total length: 1000000
# end cycle. length: 812379	 time:2.3602967262268066
# start total length: 812379
# end cycle. length: 660401	 time:1.9944427013397217
# start total length: 660401
# end cycle. length: 537125	 time:1.627924919128418
# start total length: 537125
# end cycle. length: 437229	 time:1.2674627304077148
# start total length: 437229
# end cycle. length: 356020	 time:1.0296542644500732
# start total length: 356020
# end cycle. length: 289925	 time:0.8270695209503174
# start total length: 289925
# end cycle. length: 236094	 time:0.6655280590057373
# start total length: 236094
# end cycle. length: 192343	 time:0.5496399402618408
# start total length: 192343
# end cycle. length: 156658	 time:0.4147074222564697
# start total length: 156658
# end cycle. length: 127607	 time:0.331301212310791
# start total length: 127607
# end cycle. length: 104025	 time:0.28272199630737305
# start total length: 104025
# end cycle. length: 84847	 time:0.21735215187072754
# start total length: 84847
# end cycle. length: 69192	 time:0.18477725982666016
# start total length: 69192
# end cycle. length: 56460	 time:0.1543712615966797
# start total length: 56460
# end cycle. length: 46064	 time:0.12198472023010254
# start total length: 46064
# end cycle. length: 37619	 time:0.10456371307373047
# start total length: 37619
# end cycle. length: 30761	 time:0.08722996711730957
# start total length: 30761
# end cycle. length: 25170	 time:0.07089662551879883
# start total length: 25170
# end cycle. length: 20622	 time:0.061731815338134766
# start total length: 20622
# end cycle. length: 16876	 time:0.050477027893066406
# start total length: 16876
# end cycle. length: 13839	 time:0.04009246826171875
# start total length: 13839
# end cycle. length: 11413	 time:0.04272603988647461
# start total length: 11413
# end cycle. length: 9432	 time:0.030707359313964844
# start total length: 9432
# end cycle. length: 7811	 time:0.02333974838256836
# start total length: 7811
# end cycle. length: 6491	 time:0.025046348571777344
# start total length: 6491
# end cycle. length: 5417	 time:0.02064967155456543
# start total length: 5417
# end cycle. length: 4555	 time:0.0398554801940918
# start total length: 4555
# end cycle. length: 3849	 time:0.013048648834228516
# start total length: 3849
# end cycle. length: 3282	 time:0.010538101196289062
# start total length: 3282
# end cycle. length: 2830	 time:0.014401674270629883
# start total length: 2830
# end cycle. length: 2454	 time:0.011645317077636719
# start total length: 2454
# end cycle. length: 2157	 time:0.008765220642089844
# start total length: 2157
# end cycle. length: 1925	 time:0.008941650390625
# start total length: 1925
# end cycle. length: 1743	 time:0.006392955780029297
# start total length: 1743
# end cycle. length: 1596	 time:0.0056498050689697266
# start total length: 1596
# end cycle. length: 1482	 time:0.0045931339263916016
# start total length: 1482
# end cycle. length: 1396	 time:0.004464387893676758
# start total length: 1396
# end cycle. length: 1332	 time:0.006993532180786133
# start total length: 1332
# end cycle. length: 1283	 time:0.008810043334960938
# start total length: 1283
# end cycle. length: 1247	 time:0.007036924362182617
# start total length: 1247
# end cycle. length: 1222	 time:0.004542827606201172
# start total length: 1222
# end cycle. length: 1204	 time:0.0035827159881591797
# start total length: 1204
# end cycle. length: 1191	 time:0.0039899349212646484
# start total length: 1191
# end cycle. length: 1183	 time:0.004446268081665039
# start total length: 1183
# end cycle. length: 1177	 time:0.007241487503051758
# start total length: 1177
# end cycle. length: 1173	 time:0.004769563674926758
# start total length: 1173
# end cycle. length: 1171	 time:0.00638270378112793
# start total length: 1171
# end cycle. length: 1169	 time:0.004098415374755859
# start total length: 1169
# end cycle. length: 1168	 time:0.0033915042877197266
# start total length: 1168
# end cycle. length: 1168	 time:0.0033731460571289062
# end subsampling. length: 1168	 time:13.715457916259766
#
#
# total time: 13.960738897323608
# /usr/local/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# #### subsample with cutoff_sig = 0.1, rate = 0.6

# %%
start = time.time()
subsampled = np.asarray(subsampling(data_2D,list_desc = [],cutoff_sig=0.1,rate=0.6, method = "pykdtree"))
print("\n\ntotal time: {}".format(time.time()-start))

plot(subsampled)
# Out:
# Started NN-subsampling, original length: 1000000
# use pykdtree backend
# Subample with standard scaled data
# start total length: 1000000
# end cycle. length: 506913	 time:2.8877835273742676
# start total length: 506913
# end cycle. length: 261605	 time:1.6506106853485107
# start total length: 261605
# end cycle. length: 135737	 time:0.8106567859649658
# start total length: 135737
# end cycle. length: 70376	 time:0.4744703769683838
# start total length: 70376
# end cycle. length: 36754	 time:0.27102112770080566
# start total length: 36754
# end cycle. length: 19248	 time:0.13476276397705078
# start total length: 19248
# end cycle. length: 10245	 time:0.06911730766296387
# start total length: 10245
# end cycle. length: 5599	 time:0.04368233680725098
# start total length: 5599
# end cycle. length: 3174	 time:0.026365280151367188
# start total length: 3174
# end cycle. length: 1965	 time:0.015152215957641602
# start total length: 1965
# end cycle. length: 1394	 time:0.029608726501464844
# start total length: 1394
# end cycle. length: 1125	 time:0.004931211471557617
# start total length: 1125
# end cycle. length: 1005	 time:0.0037724971771240234
# start total length: 1005
# end cycle. length: 967	 time:0.003228902816772461
# start total length: 967
# end cycle. length: 959	 time:0.0031931400299072266
# start total length: 959
# end cycle. length: 956	 time:0.0030150413513183594
# start total length: 956
# end cycle. length: 956	 time:0.003931999206542969
# end subsampling. length: 956	 time:7.356963157653809
#
#
# total time: 7.713036775588989
# /usr/local/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# #### subsample with cutoff_sig = 0.4, rate = 0.2

# %%
start = time.time()
subsampled = np.asarray(subsampling(data_2D,list_desc = [],cutoff_sig=0.4,rate=0.2, method = "pykdtree"))
print("\n\ntotal time: {}".format(time.time()-start))

plot(subsampled)
# Out:
# Started NN-subsampling, original length: 1000000
# use pykdtree backend
# Subample with standard scaled data
# start total length: 1000000
# end cycle. length: 812495	 time:2.217349052429199
# start total length: 812495
# end cycle. length: 660362	 time:1.9722905158996582
# start total length: 660362
# end cycle. length: 537088	 time:1.5339226722717285
# start total length: 537088
# end cycle. length: 437000	 time:1.269867181777954
# start total length: 437000
# end cycle. length: 355783	 time:1.0354382991790771
# start total length: 355783
# end cycle. length: 289599	 time:0.8223226070404053
# start total length: 289599
# end cycle. length: 235894	 time:0.6808645725250244
# start total length: 235894
# end cycle. length: 192133	 time:0.5220832824707031
# start total length: 192133
# end cycle. length: 156452	 time:0.4355604648590088
# start total length: 156452
# end cycle. length: 127401	 time:0.34795284271240234
# start total length: 127401
# end cycle. length: 103723	 time:0.2733151912689209
# start total length: 103723
# end cycle. length: 84476	 time:0.22803902626037598
# start total length: 84476
# end cycle. length: 68773	 time:0.1846027374267578
# start total length: 68773
# end cycle. length: 56027	 time:0.1519758701324463
# start total length: 56027
# end cycle. length: 45636	 time:0.12804889678955078
# start total length: 45636
# end cycle. length: 37172	 time:0.11655116081237793
# start total length: 37172
# end cycle. length: 30250	 time:0.08629083633422852
# start total length: 30250
# end cycle. length: 24641	 time:0.07364749908447266
# start total length: 24641
# end cycle. length: 20079	 time:0.05761408805847168
# start total length: 20079
# end cycle. length: 16370	 time:0.04673409461975098
# start total length: 16370
# end cycle. length: 13325	 time:0.04411721229553223
# start total length: 13325
# end cycle. length: 10845	 time:0.0390772819519043
# start total length: 10845
# end cycle. length: 8843	 time:0.0326237678527832
# start total length: 8843
# end cycle. length: 7208	 time:0.023881196975708008
# start total length: 7208
# end cycle. length: 5864	 time:0.025913000106811523
# start total length: 5864
# end cycle. length: 4794	 time:0.01429128646850586
# start total length: 4794
# end cycle. length: 3913	 time:0.013711929321289062
# start total length: 3913
# end cycle. length: 3194	 time:0.009550094604492188
# start total length: 3194
# end cycle. length: 2606	 time:0.008409261703491211
# start total length: 2606
# end cycle. length: 2131	 time:0.010026931762695312
# start total length: 2131
# end cycle. length: 1740	 time:0.007813453674316406
# start total length: 1740
# end cycle. length: 1431	 time:0.005255460739135742
# start total length: 1431
# end cycle. length: 1172	 time:0.004716396331787109
# start total length: 1172
# end cycle. length: 967	 time:0.005036354064941406
# start total length: 967
# end cycle. length: 799	 time:0.0034677982330322266
# start total length: 799
# end cycle. length: 662	 time:0.004179239273071289
# start total length: 662
# end cycle. length: 553	 time:0.003041982650756836
# start total length: 553
# end cycle. length: 463	 time:0.003772735595703125
# start total length: 463
# end cycle. length: 389	 time:0.002437114715576172
# start total length: 389
# end cycle. length: 331	 time:0.0023016929626464844
# start total length: 331
# end cycle. length: 284	 time:0.002129793167114258
# start total length: 284
# end cycle. length: 248	 time:0.0019221305847167969
# start total length: 248
# end cycle. length: 215	 time:0.00196075439453125
# start total length: 215
# end cycle. length: 189	 time:0.0018894672393798828
# start total length: 189
# end cycle. length: 170	 time:0.028688907623291016
# start total length: 170
# end cycle. length: 154	 time:0.00731348991394043
# start total length: 154
# end cycle. length: 142	 time:0.001756429672241211
# start total length: 142
# end cycle. length: 131	 time:0.0017063617706298828
# start total length: 131
# end cycle. length: 123	 time:0.0015628337860107422
# start total length: 123
# end cycle. length: 116	 time:0.0016148090362548828
# start total length: 116
# end cycle. length: 112	 time:0.006496906280517578
# start total length: 112
# end cycle. length: 109	 time:0.002986907958984375
# start total length: 109
# end cycle. length: 106	 time:0.0019359588623046875
# start total length: 106
# end cycle. length: 104	 time:0.0027399063110351562
# start total length: 104
# end cycle. length: 103	 time:0.0032515525817871094
# start total length: 103
# end cycle. length: 102	 time:0.001596689224243164
# start total length: 102
# end cycle. length: 102	 time:0.0015115737915039062
# end subsampling. length: 102	 time:13.430898427963257
#
#
# total time: 13.615150690078735
# /usr/local/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ### Test 2: batch subsample test
#
# Batch subsampling with 100,000 and 10,000 batch sizes were tested. 2 observations could be made:
#
# 1. subsampling based on small batchs sucessfully lowered the cost of the subsampling algorithm
# 2. seems the resulting sabsampled datasets are much more sparse
#
# #### 100000 datapoints in a batch, with 2 levels of batch subsample
# subsample with cutoff_sig = 0.1, rate = 0.2

# %%
start = time.time()
subsampled = np.array(batch_subsampling(data_2D,list_desc = [], batch_size = 100000, recursive_level = 1, \
                                                      cutoff_sig=0.1,rate=0.2, method = "pykdtree",verbose = False))

print("total time: {}".format(time.time()-start))

plot(subsampled)
# Out:
# at recursive level 1, length 1000000
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 811	 time:0.7647104263305664
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 859	 time:1.0097017288208008
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 874	 time:1.1311743259429932
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 891	 time:1.1159617900848389
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 861	 time:1.1335535049438477
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 851	 time:1.1208245754241943
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 877	 time:1.2303094863891602
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 894	 time:1.1379194259643555
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 887	 time:1.2563304901123047
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 899	 time:1.1104769706726074
# (8704, 2)
# at recursive level 1, length 1, Overall subsample
# Started NN-subsampling, original length: 8704
# use pykdtree backend
# end subsampling. length: 343	 time:0.11079716682434082
# total time: 12.970992803573608
# /usr/local/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
start = time.time()
temp_subsampled = np.array(batch_subsampling(data_2D,list_desc = [], batch_size = 10000, recursive_level = 2, \
                                                      cutoff_sig=0.1,rate=0.2, method = "pykdtree",verbose = False))

print("total time: {}".format(time.time()-start))

plot(subsampled)
# Out:
# at recursive level 2, length 1000000
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 463	 time:0.06672120094299316
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 520	 time:0.13485193252563477
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 539	 time:0.1194615364074707
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 575	 time:0.1489570140838623
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 567	 time:0.11355328559875488
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 582	 time:0.11657977104187012
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 564	 time:0.11665987968444824
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 581	 time:0.12397241592407227
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 589	 time:0.13061285018920898
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 565	 time:0.12391185760498047
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 608	 time:0.13167905807495117
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 597	 time:0.1643667221069336
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 590	 time:0.14078330993652344
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 588	 time:0.1253662109375
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 609	 time:0.1318495273590088
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 574	 time:0.13245820999145508
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 575	 time:0.13066339492797852
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 600	 time:0.1360478401184082
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 589	 time:0.13328099250793457
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 584	 time:0.2075650691986084
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 584	 time:0.19040250778198242
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 604	 time:0.15003514289855957
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 599	 time:0.153550386428833
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 585	 time:0.1303725242614746
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 595	 time:0.12972164154052734
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 583	 time:0.13385748863220215
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 595	 time:0.16515111923217773
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 593	 time:0.15354442596435547
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 596	 time:0.13468050956726074
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 595	 time:0.1304335594177246
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 591	 time:0.17368841171264648
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 613	 time:0.14589309692382812
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 609	 time:0.13051700592041016
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 595	 time:0.12447285652160645
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 583	 time:0.1307373046875
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 601	 time:0.14647889137268066
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 592	 time:0.13272953033447266
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 615	 time:0.14832282066345215
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 594	 time:0.13435149192810059
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 607	 time:0.19294357299804688
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 617	 time:0.1324934959411621
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 576	 time:0.1346118450164795
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 596	 time:0.12649822235107422
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 610	 time:0.14459633827209473
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 572	 time:0.13431239128112793
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 572	 time:0.13131213188171387
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 587	 time:0.1623821258544922
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 594	 time:0.1679821014404297
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 605	 time:0.13571500778198242
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 579	 time:0.16837787628173828
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 615	 time:0.13231730461120605
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 600	 time:0.24974846839904785
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 629	 time:0.43488621711730957
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 593	 time:0.37018394470214844
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 605	 time:0.26836323738098145
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 560	 time:0.36171674728393555
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 605	 time:0.47057151794433594
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 597	 time:0.15003418922424316
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 614	 time:0.2861669063568115
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 611	 time:0.2857701778411865
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 595	 time:0.1414327621459961
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 597	 time:0.6180310249328613
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 598	 time:0.5903646945953369
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 590	 time:0.5819849967956543
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 596	 time:0.48734259605407715
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 590	 time:0.41031837463378906
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 616	 time:0.5263798236846924
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 603	 time:0.5057063102722168
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 595	 time:0.36020874977111816
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 615	 time:0.44219517707824707
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 605	 time:0.5443019866943359
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 594	 time:0.407548189163208
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 596	 time:0.13123059272766113
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 595	 time:0.14257240295410156
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 591	 time:0.1462407112121582
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 597	 time:0.1308603286743164
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 613	 time:0.14029479026794434
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 591	 time:0.22237706184387207
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 611	 time:0.14407658576965332
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 607	 time:0.13590478897094727
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 593	 time:0.13281464576721191
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 599	 time:0.1452341079711914
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 598	 time:0.13344717025756836
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 597	 time:0.14758896827697754
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 622	 time:0.1315760612487793
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 593	 time:0.1311652660369873
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 612	 time:0.1351463794708252
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 575	 time:0.16910791397094727
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 613	 time:0.148651123046875
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 578	 time:0.13173460960388184
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 596	 time:0.1514585018157959
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 604	 time:0.1314241886138916
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 592	 time:0.1524219512939453
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 608	 time:0.13778090476989746
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 592	 time:0.13529610633850098
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 605	 time:0.14643359184265137
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 592	 time:0.1736924648284912
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 585	 time:0.13218021392822266
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 574	 time:0.13080883026123047
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 617	 time:0.13553857803344727
# (59265, 2)
# end recursive level 2, length 59265, Continue
# at recursive level 1, length 59265
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 391	 time:0.13956117630004883
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 406	 time:0.23702716827392578
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 405	 time:0.19654083251953125
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 391	 time:0.16791987419128418
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 390	 time:0.12958693504333496
# Started NN-subsampling, original length: 9265
# use pykdtree backend
# end subsampling. length: 383	 time:0.11901354789733887
# (2366, 2)
# at recursive level 1, length 1, Overall subsample
# Started NN-subsampling, original length: 2366
# use pykdtree backend
# end subsampling. length: 267	 time:0.03895926475524902
# total time: 22.595748901367188
# /usr/local/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ### Test 3: scaling in multiple dimensions with different backend
#
# 2 different backends were tested
#
# 1. pykdtree backend seems to be very efficient for lower dimension dataset, but scales badly with number of dimensions
#
# 2. nmslib backed performed much worse for lower dimension datasets, but scales better with dimension
#
# #### pykdtree backend

# %%
temp = np.column_stack((x1,x2))
start = time.time()
subsampling(temp,list_desc = [], cutoff_sig=1.0,rate=0.2, method = "pykdtree",verbose = False)

print("2 dimensions, total time: {}\n\n".format(time.time()-start))

temp = np.column_stack((x1,x2,x3,x4,x5))
start = time.time()
subsampling(temp,list_desc = [], cutoff_sig=1.0,rate=0.2, method = "pykdtree",verbose = False)

print("5 dimensions,total time: {}\n\n".format(time.time()-start))

temp = np.column_stack((x1,x2,x3,x4,x5,x6,x7,x8,x9,x10))
start = time.time()
subsampling(temp,list_desc = [], cutoff_sig=1.0,rate=0.2, method = "pykdtree",verbose = False)

print("10 dimensions total time: {}\n\n".format(time.time()-start))
# Out:
# Started NN-subsampling, original length: 1000000
# use pykdtree backend
# end subsampling. length: 25	 time:13.007389068603516
# 2 dimensions, total time: 13.233220100402832
#
#
# Started NN-subsampling, original length: 1000000
# use pykdtree backend
# end subsampling. length: 194	 time:28.179255962371826
# 5 dimensions,total time: 28.34602165222168
#
#
# Started NN-subsampling, original length: 1000000
# use pykdtree backend
# end subsampling. length: 1492	 time:629.8177185058594
# 10 dimensions total time: 630.0295593738556

# %% [markdown]
# #### nmslib backend

# %%
temp = np.column_stack((x1,x2))
start = time.time()
subsampling(temp,list_desc = [], cutoff_sig=1.0,rate=0.2, method = "nmslib",verbose = False)

print("2 dimensions, total time: {}\n\n".format(time.time()-start))

temp = np.column_stack((x1,x2,x3,x4,x5))
start = time.time()
subsampling(temp,list_desc = [], cutoff_sig=1.0,rate=0.2, method = "nmslib",verbose = False)

print("5 dimensions,total time: {}\n\n".format(time.time()-start))

temp = np.column_stack((x1,x2,x3,x4,x5,x6,x7,x8,x9,x10))
start = time.time()
subsampling(temp,list_desc = [], cutoff_sig=1.0,rate=0.2, method = "nmslib",verbose = False)

print("10 dimensions total time: {}\n\n".format(time.time()-start))
# Out:
# Started NN-subsampling, original length: 1000000
# use nmslib backend
# end subsampling. length: 23	 time:194.06100511550903
# 2 dimensions, total time: 194.26997423171997
#
#
# Started NN-subsampling, original length: 1000000
# use nmslib backend
# end subsampling. length: 181	 time:320.51497316360474
# 5 dimensions,total time: 320.6615355014801
#
#
# Started NN-subsampling, original length: 1000000
# use nmslib backend
# end subsampling. length: 1416	 time:653.84796667099
# 10 dimensions total time: 654.0281167030334

# %% [markdown]
# ### Test 4: 10 dimension dataset batch subsample with PCA pre-processing
#
# test PCA subsampling and batch PCA subsampling
#
# The test shows that
# 1. for higher dimension data, PCA preprocessing can help reducing the dimension hence the cost of the subsampling procedure
#
# 2. Again, with batch subsampling, the cost was reduced, although it seems less datapoints were kept

# %%
temp = np.column_stack((x1,x2,x3,x4,x5,x6,x7,x8,x9,x10))

start = time.time()
subsampling_with_PCA(temp,list_desc = [], start_trial_component = 5, max_component = 10, target_variance = 0.99, \
                          cutoff_sig=1.0,rate=0.2, \
                          method = "pykdtree",verbose = False)
print("without batch, total time: {}\n\n".format(time.time()-start))

start = time.time()
batch_subsampling_with_PCA(temp,list_desc = [], start_trial_component = 5, max_component = 10, target_variance = 0.99, \
                          cutoff_sig=1.0,rate=0.2, batch_size = 100000, recursive_level = 2, \
                          method = "pykdtree",verbose = False)

print("100000 batch size, total time: {}\n\n".format(time.time()-start))

start = time.time()
batch_subsampling_with_PCA(temp,list_desc = [], start_trial_component = 5, max_component = 10, target_variance = 0.99, \
                          cutoff_sig=1.0,rate=0.2, batch_size = 10000, recursive_level = 2, \
                          method = "pykdtree",verbose = False)

print("10000 batch size, total time: {}\n\n".format(time.time()-start))
# Out:
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 2.0998806953430176 s
# Started NN-subsampling, original length: 1000000
# use pykdtree backend
# end subsampling. length: 194	 time:26.412404775619507
# without batch, total time: 28.655890464782715
#
#
# at recursive level 2, length 1000000
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.11124944686889648 s
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 116	 time:0.9406478404998779
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.11068391799926758 s
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 121	 time:1.3137664794921875
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.10711431503295898 s
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 129	 time:1.4136459827423096
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.10375809669494629 s
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 127	 time:1.4361114501953125
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.11456489562988281 s
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 130	 time:1.3994688987731934
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.10568642616271973 s
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 127	 time:1.5655484199523926
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.10717630386352539 s
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 127	 time:1.369685411453247
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.09987115859985352 s
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 120	 time:1.4166646003723145
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.10837244987487793 s
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 131	 time:1.5009660720825195
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.10608291625976562 s
# Started NN-subsampling, original length: 100000
# use pykdtree backend
# end subsampling. length: 117	 time:1.4708209037780762
# end recursive level 2, length 1245, Continue
# at recursive level 1, length 1245
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.003139972686767578 s
# Started NN-subsampling, original length: 1245
# use pykdtree backend
# end subsampling. length: 15	 time:0.08378052711486816
# at recursive level 1, length 1, Overall subsample
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.007621288299560547 s
# Started NN-subsampling, original length: 15
# use pykdtree backend
# end subsampling. length: 10	 time:0.006533384323120117
# 100000 batch size, total time: 16.76000666618347
#
#
# at recursive level 2, length 1000000
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008856058120727539 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 47	 time:0.13357114791870117
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.026961565017700195 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 66	 time:0.15888118743896484
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.023325443267822266 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 63	 time:0.17565059661865234
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.02767038345336914 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 66	 time:0.2038564682006836
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.0347597599029541 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 78	 time:0.24448490142822266
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.00887298583984375 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 67	 time:0.16836833953857422
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.02300882339477539 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 77	 time:0.1702861785888672
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.009806156158447266 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 79	 time:0.17905950546264648
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008509635925292969 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 76	 time:0.1911182403564453
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03211379051208496 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 70	 time:0.19343996047973633
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.02875208854675293 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 74	 time:0.185408353805542
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.007827043533325195 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 76	 time:0.18242287635803223
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008831977844238281 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 77	 time:0.21518778800964355
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.0331578254699707 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 78	 time:0.22934246063232422
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.023093461990356445 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 66	 time:0.21665430068969727
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.017840147018432617 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 75	 time:0.20897698402404785
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.009151458740234375 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 80	 time:0.18265604972839355
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.024770498275756836 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 82	 time:0.19611430168151855
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.04002094268798828 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 77	 time:0.19782137870788574
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03903985023498535 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 67	 time:0.2048342227935791
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008820056915283203 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 73	 time:0.22075891494750977
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.023479461669921875 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 71	 time:0.24246740341186523
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.032373905181884766 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 82	 time:0.2407824993133545
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.01754140853881836 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 75	 time:0.2447192668914795
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.011139154434204102 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 71	 time:0.22949528694152832
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.027532577514648438 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 76	 time:0.22371292114257812
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03279757499694824 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 73	 time:0.23075628280639648
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.02674126625061035 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 81	 time:0.23728609085083008
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.011348247528076172 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 68	 time:0.2461850643157959
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.023501157760620117 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 79	 time:0.2360517978668213
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.018352746963500977 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 72	 time:0.24268174171447754
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.02669072151184082 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 73	 time:0.21621966361999512
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03381800651550293 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 82	 time:0.20590949058532715
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008216381072998047 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 89	 time:0.1623990535736084
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.009576559066772461 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 75	 time:0.17973899841308594
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.00891876220703125 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 77	 time:0.21321487426757812
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.02574920654296875 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 83	 time:0.20985770225524902
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.027936220169067383 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 78	 time:0.2339324951171875
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008052349090576172 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 81	 time:0.2605574131011963
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.036241769790649414 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 76	 time:0.22118067741394043
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008967399597167969 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 72	 time:0.18862104415893555
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.010073184967041016 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 79	 time:0.19959807395935059
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03074502944946289 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 71	 time:0.20013141632080078
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03985238075256348 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 76	 time:0.1988685131072998
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03803420066833496 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 81	 time:0.183610200881958
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008353471755981445 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 77	 time:0.1965923309326172
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.0078277587890625 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 79	 time:0.2594623565673828
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.022097110748291016 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 79	 time:0.26780200004577637
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.021727561950683594 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 82	 time:0.21868610382080078
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.034209489822387695 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 72	 time:0.221815824508667
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.009242773056030273 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 80	 time:0.18743538856506348
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.012882232666015625 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 76	 time:0.20520687103271484
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03078460693359375 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 75	 time:0.23598599433898926
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.02510356903076172 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 83	 time:0.23928093910217285
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03298068046569824 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 82	 time:0.24090814590454102
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.019081592559814453 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 83	 time:0.2509162425994873
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.030234813690185547 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 70	 time:0.22524642944335938
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.0192563533782959 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 85	 time:0.22856450080871582
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.028730392456054688 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 92	 time:0.21561360359191895
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008319377899169922 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 72	 time:0.24094915390014648
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.0259244441986084 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 87	 time:0.22025537490844727
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008225202560424805 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 74	 time:0.23516130447387695
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.030896425247192383 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 72	 time:0.18448567390441895
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.038537025451660156 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 79	 time:0.2148735523223877
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008486032485961914 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 67	 time:0.22028040885925293
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.027950286865234375 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 79	 time:0.22061443328857422
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03149890899658203 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 81	 time:0.24412155151367188
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03350257873535156 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 79	 time:0.22174358367919922
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.024717092514038086 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 80	 time:0.20641422271728516
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.018494606018066406 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 74	 time:0.22969889640808105
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008260011672973633 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 74	 time:0.21629786491394043
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.038127899169921875 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 69	 time:0.20145249366760254
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.019373416900634766 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 70	 time:0.22496461868286133
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03255629539489746 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 81	 time:0.22089219093322754
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.029337167739868164 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 83	 time:0.22454166412353516
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.02707052230834961 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 82	 time:0.20194554328918457
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03075242042541504 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 86	 time:0.2130422592163086
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.027558326721191406 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 83	 time:0.23413705825805664
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.017414331436157227 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 80	 time:0.2079758644104004
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.017134666442871094 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 76	 time:0.22126126289367676
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.019432783126831055 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 69	 time:0.21005678176879883
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.017485857009887695 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 79	 time:0.23195219039916992
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.016700267791748047 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 74	 time:0.25002074241638184
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.024438858032226562 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 84	 time:0.2279982566833496
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008406639099121094 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 81	 time:0.30184245109558105
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.022548913955688477 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 81	 time:0.2310502529144287
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.00799560546875 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 80	 time:0.22765898704528809
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008237123489379883 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 72	 time:0.25016093254089355
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.031960248947143555 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 86	 time:0.23760390281677246
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03709530830383301 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 79	 time:0.22199416160583496
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.034297943115234375 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 83	 time:0.21261954307556152
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.011964559555053711 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 70	 time:0.2601277828216553
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.019056081771850586 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 74	 time:0.25302982330322266
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.009799718856811523 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 76	 time:0.257282018661499
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.010033369064331055 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 71	 time:0.18719267845153809
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.01938629150390625 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 70	 time:0.1838853359222412
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.00848388671875 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 71	 time:0.19765257835388184
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.008684873580932617 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 83	 time:0.18494629859924316
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.04317831993103027 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 71	 time:0.19939136505126953
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.03940010070800781 s
# Started NN-subsampling, original length: 10000
# use pykdtree backend
# end subsampling. length: 76	 time:0.22278213500976562
# end recursive level 2, length 7628, Continue
# at recursive level 1, length 7628
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.011574268341064453 s
# Started NN-subsampling, original length: 7628
# use pykdtree backend
# end subsampling. length: 17	 time:0.12915420532226562
# at recursive level 1, length 1, Overall subsample
# start trial PCA
# end trial PCA, number of PC kept: 5 	 took 0.025374174118041992 s
# Started NN-subsampling, original length: 17
# use pykdtree backend
# end subsampling. length: 10	 time:0.10268235206604004
# 10000 batch size, total time: 26.051771879196167

# %% [markdown]
# ### Test 5: MNIST dataset test
#
# subsampling with PCA pre-processing and different backends

# %%
from mlxtend.data import loadlocal_mnist
from matplotlib import pyplot as plt

X, y = loadlocal_mnist(
        images_path='./train-images-idx3-ubyte', 
        labels_path='./train-labels-idx1-ubyte')

# %%
result = subsampling_with_PCA(X,list_desc = [],standard_scale = False, max_component = 120, target_variance = 0.98,\
                                     cutoff_sig=1.5,rate=0.1, method = "nmslib", verbose = False)
for image in result:
    plt.figure(figsize=(2,2))
    plt.imshow(image.reshape(28,28))
    plt.show()
# Out:
# start trial PCA
# stopped PCA at 121 components, total explained variance: 0.9318470573979855
# end trial PCA, number of PC kept: 121 	 took 22.71196150779724 s
# Started NN-subsampling, original length: 60000
# use nmslib backend
# end subsampling. length: 11	 time:49.66502380371094

# %%
result = subsampling_with_PCA(X,list_desc = [],standard_scale = False, max_component = 120, target_variance = 0.98,\
                                     cutoff_sig=1.5,rate=0.1, method = "pykdtree", verbose = False)
for image in result:
    plt.figure(figsize=(2,2))
    plt.imshow(image.reshape(28,28))
    plt.show()
# Out:
# start trial PCA
# stopped PCA at 121 components, total explained variance: 0.9318470573979866
# end trial PCA, number of PC kept: 121 	 took 21.786736011505127 s
# Started NN-subsampling, original length: 60000
# use pykdtree backend

# %%
result = subsampling_with_PCA(X,list_desc = [],standard_scale = False, max_component = 120, target_variance = 0.98,\
                                     cutoff_sig=1.5,rate=0.1, method = "annoy", verbose = False)
for image in result:
    plt.figure(figsize=(2,2))
    plt.imshow(image.reshape(28,28))
    plt.show()

# %% [markdown]
# ### Test 6: fashion-MNIST dataset test
#
# subsampling with PCA pre-processing and different backend

# %%
X, y = loadlocal_mnist(
        images_path='./train-fasion-images-idx3-ubyte', 
        labels_path='./train-fasion-labels-idx1-ubyte')

# %%
result = subsampling_with_PCA(X,list_desc = [],standard_scale = False, max_component = 120, target_variance = 0.98,\
                                     cutoff_sig=1.5,rate=0.1, method = "nmslib", verbose = False)
for image in result:
    plt.figure(figsize=(2,2))
    plt.imshow(image.reshape(28,28))
    plt.show()

# %%
result = subsampling_with_PCA(X,list_desc = [],standard_scale = False, max_component = 120, target_variance = 0.98,\
                                     cutoff_sig=1.5,rate=0.1, method = "pykdtree", verbose = False)
for image in result:
    plt.figure(figsize=(2,2))
    plt.imshow(image.reshape(28,28))
    plt.show()

# %%
result = subsampling_with_PCA(X,list_desc = [],standard_scale = False, max_component = 120, target_variance = 0.98,\
                                     cutoff_sig=1.5,rate=0.1, method = "annoy", verbose = False)
for image in result:
    plt.figure(figsize=(2,2))
    plt.imshow(image.reshape(28,28))
    plt.show()
